# %%
##plot dos and pdos from vasprun.xml for a 2116 compound
from bsdos import *
c = "Rb2In1Sc1Br6"
v = Vasprun("/Users/yao/Google Drive/data/2116/eff_mass_analysis/"+c+"/vasprun.xml")
fig = plt.figure(figsize=(16,10))
gs = gridspec.GridSpec(1, 4, width_ratios=[1, 1, 1, 1]) 

ylim = [-8, 12]
plt.subplot(gs[0])
draw_total_dos(v, [0, 40], ylim)
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))

ele_list = re.split('1|2|6', c)
A, B1, B2, X = ele_list[0], ele_list[1], ele_list[2], ele_list[3]

plt.subplot(gs[1])
draw_pdos(v, B1, [0, 5], ylim)

plt.subplot(gs[2])
draw_pdos(v, B2, [0, 5], ylim)

plt.subplot(gs[3])
draw_pdos(v, X, [0, 5], ylim)

plt.savefig('/Users/yao/Google Drive/data/2116/eff_mass_analysis/dos/'+c+'_PBE_DOS.pdf',dpi=300, bbox_inches='tight')
plt.show()
# Out:
# //anaconda/envs/216paper/lib/python3.5/site-packages/pymatgen/io/vasp/outputs.py:814: UserWarning: No POTCAR file with matching TITEL fields was found in /Users/yao/Google Drive/data/2116/eff_mass_analysis/Rb2In1Sc1Br6
#   " was found in {}".format(os.path.abspath(p)))
